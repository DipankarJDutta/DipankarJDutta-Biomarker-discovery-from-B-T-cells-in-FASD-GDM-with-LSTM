# %% [markdown]
# <a href="https://colab.research.google.com/github/DipankarJDutta/DipankarJDutta-Biomarker-discovery-from-B-T-cells-in-FASD-GDM-with-LSTM/blob/Weights-%26-Biases/LSTM_B_T_Median_optimized%20model_W%26B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install WandB
# !pip install wandb

# %%
# Loading essentials
import numpy as np
from numpy import loadtxt
from numpy import reshape
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

# %%
#Initialize WandB
import wandb
from wandb.keras import WandbCallback
wandb.init(project = "B-T-LSTM_WandB")
wandb.init(config={"hyper":"parameter"})
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/dipankarjdutta/B-T-LSTM_WandB" target="_blank">https://app.wandb.ai/dipankarjdutta/B-T-LSTM_WandB</a><br/>
#                 Run page: <a href="https://app.wandb.ai/dipankarjdutta/B-T-LSTM_WandB/runs/ibk94s4e" target="_blank">https://app.wandb.ai/dipankarjdutta/B-T-LSTM_WandB/runs/ibk94s4e</a><br/>
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/dipankarjdutta/B-T-LSTM_WandB" target="_blank">https://app.wandb.ai/dipankarjdutta/B-T-LSTM_WandB</a><br/>
# ...

# %%
# Fixing random seed to 007 for reproducibility
from numpy.random import seed
seed(7)
from tensorflow import set_random_seed
set_random_seed(7)

# %%
# Load data
dataset = loadtxt('B-T-median.csv', delimiter = ',')

# %%
# Reshape 2D dataset into a 3D dataset with columns as features with one time-step
x = dataset.reshape(56, 1, 30)

# %%
#Specify binary output of good (1) and bad (0) learners, y, in x & print y. Learner type differentiated by population median.
y = x [:, :, -1]

# %%
# Define LSTM One-to-One Model with 3 LSTM cells (determined via hyperparameter optimization). Sigmoid activation on the output layer for binary classification.
model = Sequential()
model.add(LSTM(3, input_shape=(1,30)))
model.add(Dense(1, activation='sigmoid'))

# %%
#Compile the model 
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Fit the model with a 80-20 split of dataset & shuffling sample order within an epoch. Batch size updated to 8 to be an even factor of sample size of 56.
model.fit(x, y, validation_split = 0.2, batch_size = 8, epochs = 1000, shuffle = True, callbacks=[WandbCallback()])
# Out:
# Train on 44 samples, validate on 12 samples
# Epoch 1/1000
# 44/44 [==============================] - 2s 38ms/step - loss: 0.7078 - acc: 0.4545 - val_loss: 0.7240 - val_acc: 0.4167
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151957). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# Epoch 2/1000
# 44/44 [==============================] - 0s 661us/step - loss: 0.7052 - acc: 0.4545 - val_loss: 0.7205 - val_acc: 0.4167
# Epoch 3/1000
# 44/44 [==============================] - 0s 573us/step - loss: 0.7029 - acc: 0.4545 - val_loss: 0.7171 - val_acc: 0.4167
# Epoch 4/1000
# 44/44 [==============================] - 0s 630us/step - loss: 0.7008 - acc: 0.4545 - val_loss: 0.7143 - val_acc: 0.4167
# Epoch 5/1000
# 44/44 [==============================] - 0s 514us/step - loss: 0.6991 - acc: 0.4545 - val_loss: 0.7113 - val_acc: 0.4167
# Epoch 6/1000
# ...

# %%
#Installing h5py Python library to save trained models
# !pip install h5py

# %%
#Save final keras LSTM Model locally and in WandB
model.save('B-T-median_LSTM.h5')
wandb.save("B-T-median_LSTM.h5")
# Out:
# []
