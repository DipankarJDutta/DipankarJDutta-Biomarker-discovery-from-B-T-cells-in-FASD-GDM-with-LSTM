# %% [markdown]
# <a href="https://colab.research.google.com/github/DipankarJDutta/DipankarJDutta-Biomarker-discovery-from-B-T-cells-in-FASD-GDM-with-LSTM/blob/Visualisation/RBP%20binding%20heatmap_downreg%20to%20upreg%20exon%20ratio_cell-type_treatment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fixing random seed to 007 for reproducibility
from numpy.random import seed
seed(7)
from tensorflow import set_random_seed
set_random_seed(7)

# %%
# Importing essentials
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data
dataset = pd.read_csv('SE_RBP analysis_B_M_T_EtOH_GDM_Seaborn_input.csv')

# %%
# Display all data
dataset.head(100)
# Out:
#     B-cell -EtOH  B-cell - GDM  ...  Monocyte -EtOH  Monocyte - GDM
# 0       0.989897      0.965918  ...        0.894118        1.057416
# 1       1.062241      0.982864  ...        0.941176        0.989429
# 2       0.983647      0.912183  ...        0.879795        0.911688
# 3       0.974625      0.923735  ...        0.920716        0.911688
# 4       0.977593      0.962016  ...        0.990712        0.787879
# ..           ...           ...  ...             ...             ...
# 89      1.095199      0.879153  ...        1.000000        0.933014
# 90      1.479253      0.606312  ...        1.647059        1.181818
# 91      0.900415      0.898769  ...        0.941176        0.927273
# 92      1.057630      0.933721  ...        0.941176        0.997159
# 93      0.949009      0.965918  ...        0.829132        0.886364
#
# [94 rows x 6 columns]

# %%
# Describe the data; 56 samples, range of 0 to 1 (not z-scored)
dataset.describe()
# Out:
#        B-cell -EtOH  B-cell - GDM  ...  Monocyte -EtOH  Monocyte - GDM
# count     94.000000     94.000000  ...       94.000000       94.000000
# mean       1.030037      0.925411  ...        0.931837        0.900931
# std        0.146889      0.098168  ...        0.168190        0.178388
# min        0.840037      0.606312  ...        0.579186        0.000000
# 25%        0.954857      0.878369  ...        0.847059        0.851566
# 50%        0.993672      0.923297  ...        0.917647        0.911688
# 75%        1.058627      0.965586  ...        0.998366        0.984848
# max        1.915168      1.257537  ...        1.882353        1.636364
#
# [8 rows x 6 columns]

# %%
# Set Seaborn Style defaults
sns.set(style = 'ticks', font= 'sans-serif', font_scale=1.25)

# %%
#Set up Matplotlib figure
f,ax = plt.subplots(figsize=(150, 75))

# Specify colors
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Plotting the heatmap with the correct aspect ratio
sns.heatmap(dataset, linewidths=1, linecolor = 'white', cmap=cmap, center=1, square=True, vmin = 0, vmax = 2, cbar_kws={'shrink':1}, annot = True, fmt='0.2g' )

#Save figure as svg
plt.savefig ('SE_RBP analysis_B_M_T_EtOH_GDM_heatmap.svg', format = 'svg')

# %%
#No annotations inside cells

#Set up Matplotlib figure
f,ax = plt.subplots(figsize=(50,25))

# Specify colors
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Plotting the heatmap with the correct aspect ratio
sns.heatmap(dataset, linewidths=0.5, linecolor = 'white', cmap=cmap, center=1, vmin = 0, vmax = 2, square=True, cbar_kws={'shrink':1})

#Save figure as svg
plt.savefig ('SE_RBP analysis_B_M_T_EtOH_GDM_heatmap_no annot.svg', format = 'svg')
