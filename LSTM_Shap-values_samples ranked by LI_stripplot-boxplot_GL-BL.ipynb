# %% [markdown]
# <a href="https://colab.research.google.com/github/DipankarJDutta/DipankarJDutta-Biomarker-discovery-from-B-T-cells-in-FASD-GDM-with-LSTM/blob/Feature-extraction-with-Shap/LSTM_Shap-values_samples%20ranked%20by%20LI_stripplot-boxplot_GL-BL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fixing random seed to 007 for reproducibility
from numpy.random import seed
seed(7)
from tensorflow import set_random_seed
set_random_seed(7)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Importing essentials
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data
dataset = pd.read_csv('Shap values_LSTM_Stripplot-input.csv')

# %%
# Display all data
dataset.head(56)
# Out:
#       Genes  Shap-values       Learner
# 0   Tnfaip3     0.002060  Good-learner
# 1   Tnfaip3     0.002140  Good-learner
# 2   Tnfaip3     0.001990  Good-learner
# 3   Tnfaip3    -0.002940  Good-learner
# 4   Tnfaip3     0.002130  Good-learner
# 5   Tnfaip3    -0.004460  Good-learner
# 6   Tnfaip3     0.001820  Good-learner
# 7   Tnfaip3    -0.000660  Good-learner
# 8   Tnfaip3    -0.003340  Good-learner
# 9   Tnfaip3    -0.002090  Good-learner
# 10  Tnfaip3     0.001970  Good-learner
# 11  Tnfaip3     0.002110  Good-learner
# 12  Tnfaip3     0.001890  Good-learner
# 13  Tnfaip3     0.001860  Good-learner
# 14  Tnfaip3     0.001930  Good-learner
# 15  Tnfaip3    -0.002510  Good-learner
# 16  Tnfaip3    -0.000320  Good-learner
# 17  Tnfaip3    -0.000518  Good-learner
# 18  Tnfaip3    -0.000759  Good-learner
# 19  Tnfaip3     0.002140  Good-learner
# 20  Tnfaip3    -0.002320  Good-learner
# 21  Tnfaip3    -0.001310  Good-learner
# 22  Tnfaip3    -0.005350  Good-learner
# 23  Tnfaip3    -0.000059  Good-learner
# 24  Tnfaip3     0.001900  Good-learner
# 25  Tnfaip3     0.002350  Good-learner
# 26  Tnfaip3     0.002170  Good-learner
# 27  Tnfaip3     0.001940  Good-learner
# 28  Tnfaip3     0.002130  Good-learner
# 29  Tnfaip3    -0.002450  Good-learner
# 30   Chchd7    -0.007900  Good-learner
# 31   Chchd7    -0.002700  Good-learner
# 32   Chchd7     0.004390  Good-learner
# 33   Chchd7    -0.010200  Good-learner
# 34   Chchd7    -0.008180  Good-learner
# 35   Chchd7    -0.000456  Good-learner
# 36   Chchd7     0.012100  Good-learner
# 37   Chchd7     0.016400  Good-learner
# 38   Chchd7    -0.002630  Good-learner
# 39   Chchd7    -0.004270  Good-learner
# 40   Chchd7     0.004880  Good-learner
# 41   Chchd7     0.008470  Good-learner
# 42   Chchd7    -0.000410  Good-learner
# 43   Chchd7    -0.013700  Good-learner
# 44   Chchd7    -0.002400  Good-learner
# 45   Chchd7    -0.002270  Good-learner
# 46   Chchd7    -0.000443  Good-learner
# 47   Chchd7     0.008970  Good-learner
# 48   Chchd7    -0.001640  Good-learner
# 49   Chchd7     0.016500  Good-learner
# 50   Chchd7    -0.006460  Good-learner
# 51   Chchd7    -0.007790  Good-learner
# 52   Chchd7     0.027300  Good-learner
# 53   Chchd7    -0.006930  Good-learner
# 54   Chchd7    -0.003420  Good-learner
# 55   Chchd7    -0.017400  Good-learner

# %%
# Describe the data; 56 samples, range of 0 to 1 (not z-scored)
dataset.describe()
# Out:
#         Shap-values
# count  1.624000e+03
# mean   4.504680e-08
# std    1.044599e-02
# min   -6.290000e-02
# 25%   -1.862500e-03
# 50%   -1.595000e-05
# 75%    2.070000e-03
# max    8.080000e-02

# %%
# Set Seaborn Style defaults
sns.set(style = 'whitegrid', font= 'sans-serif', font_scale=1.25)

# %%
# Strip plot such that good and bad learners are visually-separate:
#Set up Matplotlib figure
f,ax = plt.subplots(figsize=(60,30))

# Create an array with the green and red colors
colors = ["#006400", "#ff0000"]

# Set your custom color palette
sns.set_palette(sns.color_palette(colors))

# Plotting the heatmap with the correct aspect ratio
sns.stripplot(x='Shap-values', y='Genes', hue='Learner', data=dataset, linewidth=0.5, dodge=True, size = 10, edgecolor = 'black', alpha=0.50 )

#Save figure as svg
plt.savefig ('Strip-plot_shap_LSTM_GL-BL_dodged.svg', format = 'svg')

# %%
# Strip plot such that good and bad learners are NOT visually-separate:
#Set up Matplotlib figure
f,ax = plt.subplots(figsize=(60,30))

# Create an array with the green and red colors
colors = ["#006400", "#ff0000"]

# Set your custom color palette
sns.set_palette(sns.color_palette(colors))

# Plotting the heatmap with the correct aspect ratio
sns.stripplot(x='Shap-values', y='Genes', hue='Learner', data=dataset, linewidth=0.5, dodge=False, size = 10, edgecolor = 'black', alpha=0.50 )

#Save figure as svg
plt.savefig ('Strip-plot_shap_LSTM_GL-BL_NOT-dodged.svg', format = 'svg')

# %%
#Set up boxplot on top of non-dodged strip-plot
#Set up Matplotlib figure
f,ax = plt.subplots(figsize=(60,30))
ax = sns.boxplot(x='Shap-values', y='Genes', data=dataset, whis=np.inf, color='#e7e7e7', linewidth=0.25)
ax = sns.stripplot(x='Shap-values', y='Genes', hue='Learner', data=dataset, linewidth=0.25, dodge=False, size = 20, edgecolor = 'black', alpha=0.5)

#Save figure as svg
plt.savefig ('Strip-plot_box-plot_shap_LSTM_GL-BL_NOT-dodged.svg', format = 'svg')

# %%
#Set up boxplot on top of dodged strip-plot
#Set up Matplotlib figure
f,ax = plt.subplots(figsize=(60,30))
ax = sns.boxplot(x='Shap-values', y='Genes', data=dataset, whis=np.inf, color='#e7e7e7', linewidth=0.25)
ax = sns.stripplot(x='Shap-values', y='Genes', hue='Learner', data=dataset, linewidth=0.25, dodge=True, size = 20, edgecolor = 'black', alpha=0.5)

#Save figure as svg
plt.savefig ('Strip-plot_box-plot_shap_LSTM_GL-BL_dodged.svg', format = 'svg')
