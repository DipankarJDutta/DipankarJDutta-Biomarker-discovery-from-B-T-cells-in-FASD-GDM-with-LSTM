# %% [markdown]
# <a href="https://colab.research.google.com/github/DipankarJDutta/DipankarJDutta-Biomarker-discovery-from-B-T-cells-in-FASD-GDM-with-LSTM/blob/Peering-inside-the-Black-Box/LSTM_B-T-Median_Pairplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fixing random seed to 007 for reproducibility
from numpy.random import seed
seed(7)
from tensorflow import set_random_seed
set_random_seed(7)

# %%
# Importing essentials
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data
dataset = pd.read_csv('B-T-median_+col-names_-learner-type.csv')

# %%
# Plot Pairplot
sns.pairplot(dataset, corner=True, kind="reg")

# Set Seaborn Style
sns.set(style = "ticks")

#Save figure as svg
plt.savefig ('pairplot_B-T_median.svg', format = 'svg')

# %%
# Load dataset with learner-type
dataset_lt = pd.read_csv('B-T-median_+col-names_+learner-type.csv')

# Plot Pairplot with learner-type
sns.pairplot(dataset, hue = "Learner", corner=True)

#Save figure as svg
plt.savefig ('pairplot_B-T_median_+learner-type.svg', format = 'svg')
